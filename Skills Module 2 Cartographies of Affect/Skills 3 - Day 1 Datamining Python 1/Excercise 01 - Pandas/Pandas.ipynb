# %% [markdown]
# # Pandas in Python
#
# ![Pandas](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkKmkBqviJKR3yCj5F251eRodlrKmubG6ey7pJMGGLMs2CF23gBT_4QevLGRVUjcSXSkQ&usqp=CAU)
#
# Pandas is a library that facilitates working with tables similar to **Excel**. The difference is that Excel not being the ideal option for handling large amounts of data. This is precisely where Pandas comes in, enabling a variety of table-related operations on large datasets. The importance of Pandas cannot be overstated, as this library significantly contributes to the tremendous success of Python for data scientists.
#
# The documentation can be found [here](https://pandas.pydata.org/docs/index.html), and numerous learning resources and tutorials are available on the internet. The following document provides a brief introduction to Pandas and showcases a few important commands.
#
# Tables are referred to as *dataframes*.
#
# ![Pandas](Dataframe.png)
#
# After importing the library, a CSV file can be brought in and converted into a dataframe. For the sake of simplicity, we call the new dataframe "df."
#
# The CSV file is located within the directory, containing sample images from *Flickr* that will serve us as an example file.

# %% [markdown]
# ## Read CSV files
#
# [CSV reader](https://pandas.pydata.org/docs/user_guide/io.html#io-read-csv-table) documentation.

# %%
import pandas as pd

# %%
path = "Excercise 03 - Flickr.csv"

df = pd.read_csv(path, sep = ",")

df
# Out:
#               p_id        lat       lon             o_id               p_date  \
# 0           214028  51.504265 -0.078659  51035570500@N01  2003-05-24 17:40:38
# 1           436102  51.505937 -0.082182     40385587@N00  2004-03-16 14:02:05
# 2           436113  51.505323 -0.089650     40385587@N00  2004-03-16 14:04:28
# 3           459075  51.505062 -0.079017     98406434@N00  2004-06-27 00:00:00
# 4           459077  51.505062 -0.079017     98406434@N00  2004-06-27 00:00:00
# ...            ...        ...       ...              ...                  ...
# 89016  53282639969  51.505597 -0.083953     35234357@N04  2023-06-20 17:23:41
# 89017  53282751605  51.504722 -0.081667     35234357@N04  2023-06-20 17:29:54
# 89018  53283030331  51.505111 -0.089925     78364563@N00  2023-10-21 14:44:02
# 89019  53283300699  51.505944 -0.088692    138177073@N04  2023-06-13 19:27:27
# 89020  53283416775  51.505044 -0.078175    138177073@N04  2023-06-13 18:44:58
#
#        accuracy                                              title  \
# 0            16                                  City Hall, London
# 1            14                                Angel. A Figurehead
# 2            14                      Sign at London Bridge Station
# 3            16                         London - City Hall looming
# 4            16                      London - City Hall reflection
# ...         ...                                                ...
# 89016        16              Hays Galleria, London, 20th June 2023
# 89017        16  Apart Together by Olivia Hylton, Part of the M...
# 89018        16                                                NaN
# 89019        16                                             London
# 89020        16                                    Tower of London
#
#                                                     tags  \
# 0      london england normanfoster architecture geota...
# 1      london thames ship olympus c740 figurehead wys...
# 2                  signs london olympus lee c740 wysiwyg
# 3       london towerbridge cityhall anyhoo photobyanyhoo
# 4      reflection london thames cityhall anyhoo photo...
# ...                                                  ...
# 89016  20thjune june2023 london haysgalleria haysgall...
# 89017  20thjune june2023 london morph morphsculptures...
# 89018                                                NaN
# 89019                       london england unitedkingdom
# 89020                       london england unitedkingdom
#
#                                                      url
# 0      https://live.staticflickr.com/1/214028_a96ba3e...
# 1      https://live.staticflickr.com/1/436102_7907e51...
# 2      https://live.staticflickr.com/1/436113_d87fc68...
# 3      https://live.staticflickr.com/1/459075_44a6d3d...
# 4      https://live.staticflickr.com/1/459077_74f6ecc...
# ...                                                  ...
# 89016  https://live.staticflickr.com/65535/5328263996...
# 89017  https://live.staticflickr.com/65535/5328275160...
# 89018  https://live.staticflickr.com/65535/5328303033...
# 89019  https://live.staticflickr.com/65535/5328330069...
# 89020  https://live.staticflickr.com/65535/5328341677...
#
# [89021 rows x 9 columns]

# %% [markdown]
# ## Accessing Data
# You can access DataFrame data using these familiar looking operations:

# %%
#HOW TO ACCESS ROWS

# the first 4 rows
# df.head(4)

# the last 4 rows
# df.tail(4)

# # the rows between 5000 and 5003
# df[5000:5003]

# # or just row 8567 (index 8566)
df.iloc[8567]
# Out:
# p_id                                               2778949712
# lat                                                 51.504896
# lon                                                 -0.086688
# o_id                                             83736792@N00
# p_date                                    2008-06-01 17:35:17
# accuracy                                                   14
# title                                        20080601-City-03
# tags        city uk england building london architecture n...
# url         https://live.staticflickr.com/3213/2778949712_...
# Name: 8567, dtype: object

# %%
#HOW TO ACCESS COLUMNS

# extract a column as a list. in this case extract all titles
# df["title"]

# get the title of row 40235
df["title"][40235]
# Out:
# 'The Shard Opening 027'

# %% [markdown]
# ## .loc and .iloc
#
# As you can see, the syntax is very simlar to lists. But the result is always a list. If you want to access a datapoint an expression like `df[8566]` gives you an error message. In these cases you have to use `.loc` and `.iloc`.

# %%
# df[8566]

# get row 8567 (index 8566)
df.iloc[8567]
# Out:
# p_id                                               2778949712
# lat                                                 51.504896
# lon                                                 -0.086688
# o_id                                             83736792@N00
# p_date                                    2008-06-01 17:35:17
# accuracy                                                   14
# title                                        20080601-City-03
# tags        city uk england building london architecture n...
# url         https://live.staticflickr.com/3213/2778949712_...
# Name: 8567, dtype: object

# %% [markdown]
# Use `iloc` when your index consists of integers, such as 1, 2, 3, etc., which is typically the default case.
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b>
#
# The Flickr data file does not include an index column by default. This column was added during the import process, but its inclusion is optional.
# </div>
#
# The following code imports the same dataframe as before, this time we set the first column, `p_id`, as the index. Keep in mind that the *index* must be unique. Alternativly, an index can be a string, such as a name.

# %%
df1 = pd.read_csv(path, sep = ",", index_col = "p_id")

df1
# Out:
#                    lat       lon             o_id               p_date  \
# p_id
# 214028       51.504265 -0.078659  51035570500@N01  2003-05-24 17:40:38
# 436102       51.505937 -0.082182     40385587@N00  2004-03-16 14:02:05
# 436113       51.505323 -0.089650     40385587@N00  2004-03-16 14:04:28
# 459075       51.505062 -0.079017     98406434@N00  2004-06-27 00:00:00
# 459077       51.505062 -0.079017     98406434@N00  2004-06-27 00:00:00
# ...                ...       ...              ...                  ...
# 53282639969  51.505597 -0.083953     35234357@N04  2023-06-20 17:23:41
# 53282751605  51.504722 -0.081667     35234357@N04  2023-06-20 17:29:54
# 53283030331  51.505111 -0.089925     78364563@N00  2023-10-21 14:44:02
# 53283300699  51.505944 -0.088692    138177073@N04  2023-06-13 19:27:27
# 53283416775  51.505044 -0.078175    138177073@N04  2023-06-13 18:44:58
#
#              accuracy                                              title  \
# p_id
# 214028             16                                  City Hall, London
# 436102             14                                Angel. A Figurehead
# 436113             14                      Sign at London Bridge Station
# 459075             16                         London - City Hall looming
# 459077             16                      London - City Hall reflection
# ...               ...                                                ...
# 53282639969        16              Hays Galleria, London, 20th June 2023
# 53282751605        16  Apart Together by Olivia Hylton, Part of the M...
# 53283030331        16                                                NaN
# 53283300699        16                                             London
# 53283416775        16                                    Tower of London
#
#                                                           tags  \
# p_id
# 214028       london england normanfoster architecture geota...
# 436102       london thames ship olympus c740 figurehead wys...
# 436113                   signs london olympus lee c740 wysiwyg
# 459075        london towerbridge cityhall anyhoo photobyanyhoo
# 459077       reflection london thames cityhall anyhoo photo...
# ...                                                        ...
# 53282639969  20thjune june2023 london haysgalleria haysgall...
# 53282751605  20thjune june2023 london morph morphsculptures...
# 53283030331                                                NaN
# 53283300699                       london england unitedkingdom
# 53283416775                       london england unitedkingdom
#
#                                                            url
# p_id
# 214028       https://live.staticflickr.com/1/214028_a96ba3e...
# 436102       https://live.staticflickr.com/1/436102_7907e51...
# 436113       https://live.staticflickr.com/1/436113_d87fc68...
# 459075       https://live.staticflickr.com/1/459075_44a6d3d...
# 459077       https://live.staticflickr.com/1/459077_74f6ecc...
# ...                                                        ...
# 53282639969  https://live.staticflickr.com/65535/5328263996...
# 53282751605  https://live.staticflickr.com/65535/5328275160...
# 53283030331  https://live.staticflickr.com/65535/5328303033...
# 53283300699  https://live.staticflickr.com/65535/5328330069...
# 53283416775  https://live.staticflickr.com/65535/5328341677...
#
# [89021 rows x 8 columns]

# %%
print(df1.loc[459077])
# Out:
# lat                                                 51.505062
# lon                                                 -0.079017
# o_id                                             98406434@N00
# p_date                                    2004-06-27 00:00:00
# accuracy                                                   16
# title                           London - City Hall reflection
# tags        reflection london thames cityhall anyhoo photo...
# url         https://live.staticflickr.com/1/459077_74f6ecc...
# Name: 459077, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Summary:</b>
#
# - .iloc works on the integer value of the row. That works always.
# - .loc works on the label of the row. That works only if the row label is unique.
# </div>

# %%
# search for a specific entry like the Photo ID with the number "11869901163"

df.loc[df['p_id'] == 11869901163]
# Out:
#               p_id        lat       lon          o_id               p_date  \
# 49614  11869901163  51.505931 -0.078116  35234357@N04  2013-10-05 16:27:16
#
#        accuracy                                              title  \
# 49614        16  Barge on the Thames - Opposite the Tower of Lo...
#
#                                                     tags  \
# 49614  london october2013 shipsandboats toweroflondon...
#
#                                                      url
# 49614  https://live.staticflickr.com/5486/11869901163...

# %% [markdown]
# ## Descriptive statistics
#
# [Descriptive statistics](https://pandas.pydata.org/docs/user_guide/basics.html#descriptive-statistics)

# %%
# print(df["lat"].sum())

print(df["lat"].describe())

# %% [markdown]
# ## Data Types and Conversion

# %%
# What are the datatypes in the table?
df.dtypes

# %%
# Convert one column from int to string
df = df.astype({'p_id': 'string'})
df.dtypes

# %% [markdown]
# The trickiest part, which occurs frequently, involves managing dates and times. In its original form, a string like `2013-10-05 16:27:16` isn't automatically identified, therefore we have to convert it into a `datetime` object.
#
# `pd.to_datetime` is the command, the documentation is [here](https://pandas.pydata.org/docs/user_guide/timeseries.html).
#
# As you can see from the example below, the data is not always clean and the best is to delete it with `.drop() `

# %%
# Convert to 'p_date' to 'datetime' in order to perform date operations

# pd.to_datetime(df['p_date'])

# df.iloc[53556]

# df = df.drop(53556)

df['p_date'] = pd.to_datetime(df['p_date'])

df.dtypes
# Out:
# p_id        string[python]
# lat                float64
# lon                float64
# o_id                object
# p_date      datetime64[ns]
# accuracy             int64
# title               object
# tags                object
# url                 object
# dtype: object

# %% [markdown]
# ## Filter out data
#
# Now we can extract datapoints by date ...

# %%
filtered_df = df.query("p_date >= '2004-03-01 00:00:00' and p_date < '2004-04-01 00:00:00'")

filtered_df = filtered_df.sort_values(by='p_date', ascending=True)

filtered_df
# Out:
#               p_id        lat       lon          o_id              p_date  \
# 12144   3532394992  51.505083 -0.078449  37490392@N07 2004-03-01 22:01:14
# 87673  52805276323  51.505902 -0.083437  95012874@N00 2004-03-02 20:12:07
# 87671  52805242405  51.505902 -0.083437  95012874@N00 2004-03-02 20:12:07
# 87670  52805240045  51.505902 -0.083437  95012874@N00 2004-03-02 20:12:07
# 87669  52805235780  51.505902 -0.083437  95012874@N00 2004-03-02 20:12:07
# 87672  52805245090  51.505902 -0.083437  95012874@N00 2004-03-02 20:12:07
# 87665  52804844331  51.505902 -0.083437  95012874@N00 2004-03-02 20:12:07
# 3161     538159185  51.504956 -0.079135  19243288@N00 2004-03-10 13:45:50
# 6742    2395984590  51.504441 -0.078020  24404258@N04 2004-03-13 15:33:08
# 6734    2395154053  51.504441 -0.078020  24404258@N04 2004-03-13 16:04:34
# 6743    2395988550  51.504441 -0.078020  24404258@N04 2004-03-13 16:07:16
# 6735    2395157883  51.505002 -0.079436  24404258@N04 2004-03-13 16:14:27
# 5741    2171675644  51.505403 -0.080509  40385587@N00 2004-03-16 13:16:12
# 5792    2193519580  51.505911 -0.083405  40385587@N00 2004-03-16 13:17:17
# 1           436102  51.505937 -0.082182  40385587@N00 2004-03-16 14:02:05
# 2           436113  51.505323 -0.089650  40385587@N00 2004-03-16 14:04:28
# 5141    1825665399  51.505403 -0.080509  40385587@N00 2004-03-16 14:20:33
# 5402    2069746704  51.505403 -0.080509  40385587@N00 2004-03-16 14:26:29
# 17340   4628055206  51.505290 -0.079232  43953314@N07 2004-03-19 05:59:06
# 18874   4843868820  51.506151 -0.080595  12658277@N00 2004-03-20 05:04:54
# 18875   4843869094  51.506151 -0.080595  12658277@N00 2004-03-20 05:53:18
# 18867   4843254761  51.506151 -0.080595  12658277@N00 2004-03-20 05:54:02
# 18868   4843255005  51.504789 -0.079393  12658277@N00 2004-03-20 06:06:26
# 18869   4843255633  51.504682 -0.079607  12658277@N00 2004-03-20 06:19:12
# 18876   4843870602  51.504709 -0.079393  12658277@N00 2004-03-20 06:21:31
# 18877   4843873920  51.506151 -0.080637  12658277@N00 2004-03-20 08:33:49
#
#        accuracy                           title  \
# 12144        14                 Famous Landmark
# 87673        16                  Hay's Galleria
# 87671        16  Hay's Galleria, The Navigators
# 87670        16  Hay's Galleria, The Navigators
# 87669        16                  Hay's Galleria
# 87672        16  Hay's Galleria, The Navigators
# 87665        16  Hay's Galleria, The Navigators
# 3161         16                London City Hall
# 6742         14                          London
# 6734         14       London - The Tower Bridge
# 6743         14       London - The Tower Bridge
# 6735         14                          London
# 5741         13                     HMS Belfast
# 5792         15                   Hays Galleria
# 1            14             Angel. A Figurehead
# 2            14   Sign at London Bridge Station
# 5141         13                  London Calling
# 5402         13     Tower Bridge, Extra Seagull
# 17340        15                        DSCN4229
# 18874        16                    Inside a Gun
# 18875        16         Deck of the HMS Belfast
# 18867        16                HMS Belfast Guns
# 18868        16                London City Hall
# 18869        16                  London Skyline
# 18876        16                City Hall Spiral
# 18877        16                     HMS Belfast
#
#                                                     tags  \
# 12144  bridge london architecture towerbridge archite...
# 87673  minibreak minoltadynax5 2004 35mm film slr lon...
# 87671  minibreak minoltadynax5 2004 35mm film slr mar...
# 87670  minibreak minoltadynax5 2004 35mm film slr lon...
# 87669  spring minoltadynax5 2004 35mm epsonperfection...
# 87672  minibreak minoltadynax5 2004 35mm epsonperfect...
# 87665  minibreak minoltadynax5 2004 35mm film slr mar...
# 3161   england london tower thames river hall europe ...
# 6742                                      england london
# 6734                                              london
# 6743                                 bridge london tower
# 6735                                      england london
# 5741   bridge london thames towerbridge olympus belfa...
# 5792         london olympus c740 haysgalleria haygallery
# 1      london thames ship olympus c740 figurehead wys...
# 2                  signs london olympus lee c740 wysiwyg
# 5141                    bridge london tower olympus c740
# 5402   london tower bridge abigfave olympus c740 a3b ...
# 17340                                                NaN
# 18874                        london web shell hmsbelfast
# 18875                              london web hmsbelfast
# 18867                              london web hmsbelfast
# 18868                                london cityhall web
# 18869                                         london web
# 18876                                london cityhall web
# 18877                              london web hmsbelfast
#
#                                                      url
# 12144  https://live.staticflickr.com/3391/3532394992_...
# 87673  https://live.staticflickr.com/65535/5280527632...
# 87671  https://live.staticflickr.com/65535/5280524240...
# 87670  https://live.staticflickr.com/65535/5280524004...
# 87669  https://live.staticflickr.com/65535/5280523578...
# 87672  https://live.staticflickr.com/65535/5280524509...
# 87665  https://live.staticflickr.com/65535/5280484433...
# 3161   https://live.staticflickr.com/1204/538159185_5...
# 6742   https://live.staticflickr.com/2409/2395984590_...
# 6734   https://live.staticflickr.com/3078/2395154053_...
# 6743   https://live.staticflickr.com/2147/2395988550_...
# 6735   https://live.staticflickr.com/3121/2395157883_...
# 5741   https://live.staticflickr.com/2014/2171675644_...
# 5792   https://live.staticflickr.com/2075/2193519580_...
# 1      https://live.staticflickr.com/1/436102_7907e51...
# 2      https://live.staticflickr.com/1/436113_d87fc68...
# 5141   https://live.staticflickr.com/2217/1825665399_...
# 5402   https://live.staticflickr.com/2173/2069746704_...
# 17340  https://live.staticflickr.com/4035/4628055206_...
# 18874  https://live.staticflickr.com/4146/4843868820_...
# 18875  https://live.staticflickr.com/4154/4843869094_...
# 18867  https://live.staticflickr.com/4086/4843254761_...
# 18868  https://live.staticflickr.com/4150/4843255005_...
# 18869  https://live.staticflickr.com/4087/4843255633_...
# 18876  https://live.staticflickr.com/4104/4843870602_...
# 18877  https://live.staticflickr.com/4125/4843873920_...

# %% [markdown]
# ## Save out Data
#
# [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %%
path = "Filtered.csv"


filtered_df.to_csv(path_or_buf= path, header= True)
