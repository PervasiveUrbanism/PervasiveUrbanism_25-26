# %% [markdown]
# # Scraping Data from Tripadvisor Using Beautiful Soup
#
# Not all services provide an API for accessing their data, including popular websites such as Tripadvisor, Timeout London, and Gumtree. In cases where no API is available, we resort to extracting data directly from the webpage by parsing the HTML code.
#
# The process is relatively straightforward: the webpage is loaded into memory, and the HTML content is then searched to locate the desired information. This is made feasible by the highly structured nature of HTML pages.
#
# To accomplish this task, we require a couple of libraries. One is 'requests' (familiar to you), and the other is '***Beautiful Soup***' which assists in extracting information from a soup of HTML code. Refer to the [documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) for more details.
#
# ![](https://www.crummy.com/software/BeautifulSoup/bs4/doc/_images/6.1.jpg)

# %% [markdown]
# ## Beautiful Soup
#
# Let's get started with Beautiful Soup. We import the library and we have a look at an example:

# %%
from bs4 import BeautifulSoup

text = """
<html>
<head>
<title>
The Dormouse's story
</title>
</head>
<body>
<p class="title">
<b>
The Dormouse's story
</b>
</p>
<p class="story">
Once upon a time there were three little sisters; and their names were
<a class="sister" href="http://example.com/elsie" id="link1">
Elsie
</a>
,
<a class="sister" href="http://example.com/lacie" id="link2">
Lacie
</a>
and
<a class="sister" href="http://example.com/tillie" id="link3">
Tillie
</a>
; and they lived at the bottom of a well.
</p>
<p class="story">
...
</p>
</body>
</html>
 """

soup = BeautifulSoup(text)

# %% [markdown]
# The first command is to print the html file in a nice way.
#
# ❗You can use *sublime* as an alternative editor to inspect the code. Copy/paste the text into a new file in sublime, use "Ctrl" + "Shift" + "p" to install ["HTMLBeautify"](https://github.com/rareyman/HTMLBeautify).

# %%
print (soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ; and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# There is some parsing that can be done with simple chain commands:

# %%
print(soup.body.p.get_text())
print(soup.head.title.get_text())
# Out:
# The Dormouse's story
#
#
#
# The Dormouse's story

# %% [markdown]
# The two most used commands are `.find_all()` and `.find()`. Both are working the same way, except `.find()` returns the first match only and `.find_all() `returns all results as a list.
#
# Let's inspect the basic block of the html code:
# ```
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
# ```

# %%
name = soup.find("a", class_="sister")
print (name)
print (name.get_text())

# %%
name = soup.find("a", id="link1")
print (name)
print (name.get_text())
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie
# </a>
#
# Elsie

# %%
name = soup.find("a")
print (name)
print (name.get_text())
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie
# </a>
#
# Elsie

# %% [markdown]
# We get all the info inbetween the two tags "a". We can extract the other items like this:

# %%
text = name.get_text().strip()
print(text)

link = name ["href"]
print(link)

id = name ["id"]
print(id)
# Out:
# Elsie
# http://example.com/elsie
# link1

# %% [markdown]
# Same goes for all names:

# %%
names = soup.find_all("a", class_="sister")

for name in names:
  print(name.get_text().strip())
# Out:
# Elsie
# Lacie
# Tillie

# %% [markdown]
# This is admittibly a very short introduction to Beautiful Soup, but it covers about 95% of what you will need to scrape a webpage. And with that in mind, we can start...
#
#
#
# ⚠️ It's worth noting that if you encounter challenges in your coding excercise, you have the option to seek assistance from ***ChatGPT***. Simply input the HTML, express your intent to utilize Python Beautiful Soup, and describe the issues.
#
# ---

# %% [markdown]
# ##Scraping Tripadvisor

# %% [markdown]
# This is a full example of how to scrape data from a webpage, [Tripadvisior](https://www.tripadvisor.co.uk/Hotels-g186338-London_England-Hotels.html) in this case. The techniques are similar to other pages.
#
# <div class="markdown-google-sans">
#
# ###Getting the html and creating a soup
#
# </div>
# We load the page with requests. In this case, we identify ourselves with a header. This is a way to make the server believe that it's a genuine browser that sends the requests.

# %%
from bs4 import BeautifulSoup
import requests


url = "https://www.tripadvisor.co.uk/Hotel_Review-g186338-d10810215-Reviews-The_Montcalm_Royal_London_House-London_England.html"


headers = {
    'authority': 'www.dickssportinggoods.com',
    'pragma': 'no-cache',
    'cache-control': 'no-cache',
    'sec-ch-ua': '" Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"',
    'sec-ch-ua-mobile': '?0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'none',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'accept-language': 'en-US,en;q=0.9',
}

r = requests.get(url, headers=headers)

soup = BeautifulSoup (r.text)

print(soup.prettify())

# %% [markdown]
# ###Searching in the soup of a single entry
#
#
#
# Here we examine the page, randomly pick some items and flex our muscles...

# %%
title = soup.find_all("h1", {"class": "QdLfr b d Pn"})
print(title)

print (title[0])

print(title[0].get_text().strip())
# Out:
# [<h1 class="QdLfr b d Pn" id="HEADING">The Montcalm Royal London House</h1>]
# <h1 class="QdLfr b d Pn" id="HEADING">The Montcalm Royal London House</h1>
# The Montcalm Royal London House

# %%
title = soup.find_all("h1", class_="QdLfr b d Pn")
title[0].get_text()
# Out:
# 'The Montcalm Royal London House'

# %% [markdown]
# Take note of the distinction between `{"class": "QdLfr b d Pn"}` and `class_="QdLfr b d Pn"` in the two search examples. Although both yield identical outcomes, the usage of `class_=` is integral to Beautiful Soup's built-in search functionalities. On the other hand, the expression `{"class": "QdLfr b d Pn"}` is more generalized, allowing for the possibility of incorporating different text within it.

# %%
amount_of_reviews = soup.find_all("span", class_="qqniT")
amount_of_reviews[0].get_text()
# Out:
# '4,082 reviews'

# %%
rating = soup.find_all("span", class_="uwJeR P")
rating[0].get_text()
# Out:
# '5.0'

# %%
ranking = soup.find_all("div", class_="cGAqf")
ranking[0].get_text()

#clean up the results:
#ranking[0].get_text().split(" ")[0].replace('#', '')
# Out:
# '#21 of 1,225 hotels in London'

# %%
adress = title = soup.find_all("span", class_="fHvkI PTrfg")
adress[0].get_text()
# Out:
# 'Royal London House 22-25 Finsbury Square, London EC2A 1DX England'

# %% [markdown]
# ###Modularising the search
#
#
# Now that we have tested the search and we know that it works, we define functions. This makes it easier to modularise our code later on. The first four functions are as above. The last function combines the previous four and returns the search result as a dictionary.
#
# Having checked the functionality of our search, we continue to define functions, enhancing the modularity of our code for future adaptations. The initial four functions maintain their prior structure. The last function combine  the preceding four, presenting the search result in the form of a dictionary.

# %%
def get_name(soup):
  name = soup.find_all("h1", class_="QdLfr b d Pn")
  return name[0].get_text()

def get_adress(soup):
  adress = title = soup.find_all("span", class_="fHvkI PTrfg")
  return adress[0].get_text()

def get_ranking(soup):
  ranking = soup.find_all("div", class_="cGAqf")
  ranking = ranking[0].get_text().split(" ")[0].replace('#', '')
  return ranking

def get_amount_reviews (soup):
  amount_of_reviews = soup.find_all("span", class_="qqniT")
  return amount_of_reviews[0].get_text()





def get_info (url):
  r = requests.get(url, headers=headers)
  soup = BeautifulSoup (r.text)

  infodict = {}
  infodict["Name"] = get_name(soup)
  infodict["Adress"] = get_adress(soup)
  infodict["Ranking"] = get_ranking(soup)
  infodict["Amount_Reviews"] = get_amount_reviews(soup)
  infodict["url"] = url

  return infodict

# %% [markdown]
# ... and we test the functions

# %%
line = get_info ("https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3164384-Reviews-Park_Grand_London_Hyde_Park-London_England.html")

line
# Out:
# {'Name': 'Park Grand London Hyde Park',
#  'Adress': '78 - 82 Westbourne Terrace Paddington, London W2 6QA England',
#  'Ranking': '1',
#  'Amount_Reviews': '4,036 reviews',
#  'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3164384-Reviews-Park_Grand_London_Hyde_Park-London_England.html'}

# %% [markdown]
#  ### The Landing page
#
# Extracting links from the landing page.

# %%
main_url = "https://www.tripadvisor.co.uk/Hotels-g186338-London_England-Hotels.html"

req = requests.get(main_url, headers=headers)
soup = BeautifulSoup (req.text)

soup

# %% [markdown]
# We parse the landing page and we extract an array of links. We test and we write a function.

# %%
# that would be looking for the first link. this takes a bit of try and error to find the right expression

entries = soup.find_all("div" , {"data-automation" : "hotel-card-title"})
link= entries[21].find("a",href=True )["href"]
print(link)
# Out:
# /Hotel_Review-g186338-d1886452-Reviews-The_Hide_London-London_England.html

# %%
# that would be looking for all entries

entries = soup.find_all("div" , {"data-automation" : "hotel-card-title"})

for entry in entries[:4]:
  link = entry.find("a",href=True)['href']
  # print(entry)
  full_url = "https://www.tripadvisor.co.uk" + link
  print (full_url)
# Out:
# https://www.tripadvisor.co.uk/Hotel_Review-g186338-d602781-Reviews-Limegrove_Hotel_London-London_England.html
# https://www.tripadvisor.co.uk/Hotel_Review-g186338-d10810215-Reviews-The_Montcalm_Royal_London_House-London_England.html
# https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193062-Reviews-Park_Grand_Paddington_Court-London_England.html
# https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3164384-Reviews-Park_Grand_London_Hyde_Park-London_England.html

# %%
# now that we know it works, we combine that into a function:
# the input is the landing page and the result is a list with the links
# to the detail pages.

def get_hotel_links (url_landing):
  requ = requests.get(url_landing, headers=headers)
  bsoup = BeautifulSoup (requ.text)

  entries = bsoup.find_all("div" , {"data-automation" : "hotel-card-title"})

  hotel_links = []
  for entry in entries:
    link = entry.find("a",href=True)
    link = link['href']
    full_url = "https://www.tripadvisor.co.uk" + link
    hotel_links.append(full_url)

  return hotel_links


hotel_links = get_hotel_links(main_url)

hotel_links
# Out:
# ['https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d10810215-Reviews-The_Montcalm_Royal_London_House-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193062-Reviews-Park_Grand_Paddington_Court-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3164384-Reviews-Park_Grand_London_Hyde_Park-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d15134890-Reviews-The_Resident_Covent_Garden-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d13569031-Reviews-Travelodge_London_City_hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d242994-Reviews-Central_Hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d243667-Reviews-Travelodge_London_Kings_Cross_Royal_Scot-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193057-Reviews-Travelodge_London_Covent_Garden-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d1657415-Reviews-Park_Plaza_Westminster_Bridge_London-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23246836-Reviews-Canopy_by_Hilton_London_City-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d6484754-Reviews-Shangri_La_The_Shard_London-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3291169-Reviews-Travelodge_London_Excel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d2048553-Reviews-Leonardo_Royal_London_Tower_Bridge-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193104-Reviews-The_Clermont_London_Charing_Cross-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23950281-Reviews-Travelodge_London_Docklands_Central-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d275581-Reviews-The_Westminster_London_Curio_Collection_by_Hilton-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23246836-Reviews-Canopy_by_Hilton_London_City-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d734603-Reviews-Travelodge_London_Central_City_Road-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d313125-Reviews-Holiday_Inn_London_West_an_IHG_Hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d1886452-Reviews-The_Hide_London-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d218407-Reviews-Royal_National_Hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193097-Reviews-The_Tower_Hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d218409-Reviews-The_Clermont_Victoria-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d19975711-Reviews-The_Gate-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193143-Reviews-Park_Grand_London_Kensington-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23500323-Reviews-Wilde_Aparthotels_by_Staycity_London_Aldgate_Tower_Bridge-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193070-Reviews-The_Bailey_s_Hotel_London_Kensington-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d242994-Reviews-Central_Hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193138-Reviews-Copthorne_Tara_Hotel_London_Kensington-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d612985-Reviews-Palmers_Lodge_Swiss_Cottage-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d628205-Reviews-St_Athans_Hotel-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3530264-Reviews-Novotel_London_Blackfriars-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d14912172-Reviews-YOTEL_London_Shoreditch-London_England.html',
#  'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html']

# %% [markdown]
# ###Parsing all subsequent pages from one landing page
#
#
#
# This is the same as doing it for one entry, just that this one is in a loop. Note that there is a delay of 0.5 second inbetween the calls. This is important to account for it, otherwise the server might block the request.

# %%
import time

for hotel_link in hotel_links:
  info = get_info(hotel_link)
  print (info)
  time.sleep(0.5)
# Out:
# {'Name': 'The Savoy', 'Adress': 'The Strand, London WC2R 0EZ England', 'Ranking': '33', 'Amount_Reviews': '7,328 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html'}
# {'Name': 'Wilde Aparthotels, London, Paddington', 'Adress': '4 North Wharf Road Paddington, London W2 1NW England', 'Ranking': '12', 'Amount_Reviews': '1,190 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23500327-Reviews-Wilde_Aparthotels_London_Paddington-London_England.html'}
# {'Name': 'Hilton London Metropole', 'Adress': '225 Edgware Road, London W2 1JU England', 'Ranking': '218', 'Amount_Reviews': '1,409 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193089-Reviews-Hilton_London_Metropole-London_England.html'}
# {'Name': 'Strand Palace', 'Adress': '372 Strand, London WC2R 0JJ England', 'Ranking': '294', 'Amount_Reviews': '1,073 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193112-Reviews-Strand_Palace-London_England.html'}
# {'Name': 'The Chesterfield Mayfair', 'Adress': '35 Charles Street Mayfair, London W1J 5EB England', 'Ranking': '9', 'Amount_Reviews': '5,195 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d192064-Reviews-The_Chesterfield_Mayfair-London_England.html'}
# {'Name': 'hub by Premier Inn London Westminster Abbey hotel', 'Adress': '21 Tothill Street Westminster, London SW1H 9LL England', 'Ranking': '183', 'Amount_Reviews': '3,264 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d12895922-Reviews-Hub_by_Premier_Inn_London_Westminster_Abbey_hotel-London_England.html'}
# {'Name': 'Central Hotel', 'Adress': '16-18 Argyle Street, London WC1H 8EG England', 'Ranking': '42', 'Amount_Reviews': '686 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-
reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d287288-Reviews-The_Crown_London_Hotel-London_England.html'}
# {'Name': 'ibis Styles London Gloucester Road', 'Adress': '110 Cromwell Road, London SW7 4ES England', 'Ranking': '314', 'Amount_Reviews': '403 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html'}

# %% [markdown]
# ###Populating a Panda Dataframe
#
#
# We know that it's possible to get information for all the hotels  on the landing page. As our data volume continues to grow, there is a  need for better organization.
# In this context, a ***Panda dataframe*** proves to be the optimal solution. Now, let's revisit the same code as earlier, but this time we are generating a dataframe.

# %%
import pandas as pd

df =  pd.DataFrame()


rows_list = []
for hotel_link in hotel_links:
  info = get_info(hotel_link)
  # print(info)
  rows_list.append(info)
  time.sleep(0.5)


df = pd.DataFrame(rows_list)

df
# Out:
#                                                  Name  \
# 0                                           The Savoy
# 1               Wilde Aparthotels, London, Paddington
# 2                             Hilton London Metropole
# 3                                       Strand Palace
# 4                            The Chesterfield Mayfair
# 5   hub by Premier Inn London Westminster Abbey hotel
# 6                                       Central Hotel
# 7                                   The Resident Soho
# 8                            ibis London Canning Town
# 9                              Royal Lancaster London
# 10                         Novotel London Excel Hotel
# 11                               The Cumberland Hotel
# 12                 ibis Styles London Gloucester Road
# 13                                     The Kensington
# 14                     The Piccadilly London West End
# 15                 Travelodge London Central Waterloo
# 16                      St. James’ Court, A Taj Hotel
# 17                                              Page8
# 18                       Canopy by Hilton London City
# 19                               The Bloomsbury Hotel
# 20      Millennium Gloucester Hotel London Kensington
# 21       hub by Premier Inn London King's Cross hotel
# 22                Travelodge London Wembley High Road
# 23                        Novotel London Canary Wharf
# 24                                          The Savoy
# 25                Travelodge London Central Southwark
# 26                   Mama Shelter London - Shoreditch
# 27                                  Good Hotel London
# 28                        Premier Inn London Tolworth
# 29                                     Alhambra Hotel
# 30                                      Central Hotel
# 31                                  Mimi's Hotel Soho
# 32                         Travelodge London Finchley
# 33                              Charlotte Guest House
# 34                             The Z Hotel Piccadilly
# 35                             The Crown London Hotel
# 36                 ibis Styles London Gloucester Road
#
#                                                Adress Ranking Amount_Reviews  \
# 0                 The Strand, London WC2R 0EZ England      33  7,328 reviews
# 1   4 North Wharf Road Paddington, London W2 1NW E...      12  1,190 reviews
# 2             225 Edgware Road, London W2 1JU England     218  1,409 reviews
# 3                 372 Strand, London WC2R 0JJ England     294  1,073 reviews
# 4   35 Charles Street Mayfair, London W1J 5EB England       9  5,195 reviews
# 5   21 Tothill Street Westminster, London SW1H 9LL...     183  3,264 reviews
# 6        16-18 Argyle Street, London WC1H 8EG England      42    686 reviews
# 7          10 Carlisle Street, London W1D 3BR England      22  3,765 reviews
# 8   8 Silvertown Way Canning Town, London E16 1ED ...     120    762 reviews
# 9            Lancaster Terrace, London W2 2TY England       4  1,808 reviews
# 10  7 Western Gateway Royal Victoria Dock, London ...     229  3,237 reviews
# 11     Great Cumberland Place, London W1H 7DL England     108  3,170 reviews
# 12          110 Cromwell Road, London SW7 4ES England     314    403 reviews
# 13  109 - 113 Queen's Gate South Kensington, Londo...      27  4,218 reviews
# 14  65-73 Shaftesbury Avenue Piccadilly, London W1...      35  2,019 reviews
# 15      195-203 Waterloo Road, London SE1 8UX England     584  2,279 reviews
# 16        54 Buckingham Gate, London SW1E 6AF England     231  6,110 reviews
# 17      8 St. Martin's Place, London WC2N 4JH England      47    291 reviews
# 18            11-15 Minories, London EC3N 1AX England      37    852 reviews
# 19  16-22 Great Russell Street, London WC1B 3NN En...      20  5,068 reviews
# 20    4-18 Harrington Gardens, London SW7 4LH England     349  7,205 reviews
# 21  50 Wharfdale Road Kings Cross, London N1 9FA E...     186  3,678 reviews
# 22          High Road Wembley, London HA9 7AJ England     332  1,581 reviews
# 23              40 Marsh Wall, London E14 9TP England     311  1,839 reviews
# 24                The Strand, London WC2R 0EZ England      33  7,328 reviews
# 25  202 - 206 Union Street Southwark, London SE1 0...     655  4,525 reviews
# 26            437 Hackney Road, London E2 8PP England     104    434 reviews
# 27  Royal Victoria Dock, Western Gateway Royal Vic...     312  2,327 reviews
# 28  12 Kingston Road Tolworth, London KT5 9NU England     686    668 reviews
# 29     17 - 19 Argyle Street, London WC1H 8EJ England     327  2,387 reviews
# 30       16-18 Argyle Street, London WC1H 8EG England      42    686 reviews
# 31    56-57 Frith Street Soho, London W1D 3JG England     569    606 reviews
# 32  2 Dollis Park Road Winston House, London N3 1H...     340    734 reviews
# 33  195-197 Sumatra Road West Hampstead, London NW...      23    978 reviews
# 34           2 Orange Street, London WC2H 7DF England     355  1,719 reviews
# 35  142/152 Cricklewood Broadway, London NW2 3ED E...     519  1,892 reviews
# 36          110 Cromwell Road, London SW7 4ES England     314    403 reviews
#
#                                                   url
# 0   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 1   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 2   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 3   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 4   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 5   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 6   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 7   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 8   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 9   https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 10  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 11  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 12  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 13  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 14  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 15  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 16  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 17  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 18  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 19  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 20  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 21  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 22  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 23  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 24  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 25  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 26  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 27  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 28  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 29  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 30  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 31  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 32  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 33  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 34  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 35  https://www.tripadvisor.co.uk/Hotel_Review-g18...
# 36  https://www.tripadvisor.co.uk/Hotel_Review-g18...

# %% [markdown]
# ... and the same code as a function:

# %%
def get_all_entries (hotel_links):
  df =  pd.DataFrame()
  rows_list = []
  for hotel_link in hotel_links:
    info = get_info(hotel_link)
    print(info)
    rows_list.append(info)
    time.sleep(0.5)
  df = pd.DataFrame(rows_list)
  return df

# %% [markdown]
# <div class="markdown-google-sans">
#
# ###Filenaming
#
# </div>
#
# Ultimately, we want to save a csv file. Yet, it's always risky to have a sloppy naming convention for the files. After a little while it's hard to tell what's what and there is always the risk of accidentally overwriting the files.
#
# To help with this problem, it makes sense to write the date and time of the creation in front of the filename. This way you know which file is the latest and you can manually delete old files.

# %%
from datetime import datetime

dateTimeObj = datetime.now()
print(dateTimeObj.year, '/', dateTimeObj.month, '/', dateTimeObj.day)
print(dateTimeObj.hour, ':', dateTimeObj.minute, ':', dateTimeObj.second, '.', dateTimeObj.microsecond)

timestamp = str(dateTimeObj.year) + str(dateTimeObj.month) + str(dateTimeObj.day) +'_' + str(dateTimeObj.hour)+ str(dateTimeObj.minute) + str (dateTimeObj.second)

def filename(filename):
  dateTimeObj = datetime.now()
  timestamp = str(dateTimeObj.year) + str(dateTimeObj.month) + str(dateTimeObj.day) +'_' + str(dateTimeObj.hour)+ str(dateTimeObj.minute) + str (dateTimeObj.second)+'_'
  name = timestamp + filename + ".csv"
  return name

filename("data")
# Out:
# 2023 / 11 / 11
# 14 : 40 : 42 . 772646
# '20231111_144042_data.csv'

# %% [markdown]
# ###Scraping Strategy
#
#
#
# Tripadvisor informs us that there will be 4,424 hotel entries. Considering that each landing page has 30 entries, we can expect about 141 landing pages, each of them with a unique address.
#
# It is important that the data are safe in case a problem causes a crash while parsing a page. The best is to subsequently add data to the csv file each time python has finished parsing a page.
#
# In other words, we start with an empty text file. Each time a landing page is parsed, the text file is being opened, the data added and the file closed. This cycle repeats till the end of the overall programm. In case the program crashes, there is some data saved. This is possibly not the fastest way, but fairly easy and robust.
#
# We create the filename and the empty file.

# %%
datafile_name = filename("tripadvisor")

dt =  pd.DataFrame()

dt.to_csv(datafile_name , sep=',', encoding='utf-8')

# %% [markdown]
# We create an array of links to landing pages we like to parse:

# %%
# main_url = "https://www.tripadvisor.co.uk/Hotels-g186338-oa30-London_England-Hotels.html"

def main_url (pagenumber):
  url = "https://www.tripadvisor.co.uk/Hotels-g186338-oa"+str(pagenumber)+"-London_England-Hotels.html"
  return url

page_numbers = [30, 60, 90, 120]
page_numbers = [ 90, 120]

for page_number in page_numbers:
  print (main_url(page_number))
# Out:
# https://www.tripadvisor.co.uk/Hotels-g186338-oa90-London_England-Hotels.html
# https://www.tripadvisor.co.uk/Hotels-g186338-oa120-London_England-Hotels.html

# %% [markdown]
# And now we loop thought each page and append the data during each loop:

# %%
for page_number in page_numbers:
  url_to_get =  main_url(page_number)
  print (url_to_get)
  hotel_links = get_hotel_links(url_to_get)
  dt    =get_all_entries(hotel_links)
  dt.to_csv(datafile_name, mode='a', header=False)
# Out:
# https://www.tripadvisor.co.uk/Hotels-g186338-oa90-London_England-Hotels.html
# {'Name': 'Central Hotel', 'Adress': '16-18 Argyle Street, London WC1H 8EG England', 'Ranking': '42', 'Amount_Reviews': '686 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d242994-Reviews-Central_Hotel-London_England.html'}
# {'Name': 'The Savoy', 'Adress': 'The Strand, London WC2R 0EZ England', 'Ranking': '33', 'Amount_Reviews': '7,328 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html'}
# {'Name': "Lost Property St Paul's London - Curio Collection by Hilton", 'Adress': '3-5 Ludgate Hill, London EC4M 7AA England', 'Ranking': '26', 'Amount_Reviews': '428 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23906171-Reviews-Lost_Property_St_Paul_s_London_Curio_Collection_by_Hilton-London_England.html'}
# {'Name': 'Travelodge London Central Kings Cross', 'Adress': "Willing House 356-364 Gray's Inn Road Willings House, London WC1X 8BH England", 'Ranking': '587', 'Amount_Reviews': '3,549 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d289706-Reviews-Travelodge_London_Central_Kings_Cross-London_England.html'}
# {'Name': 'The Corner London City', 'Adress': '42, Adler Street, London E1 1EE England', 'Ranking': '207', 'Amount_Reviews': '4,326 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d4945399-Reviews-The_Corner_London_City-London_England.html'}
# {'Name': "Inhabit, Queen's Gardens", 'Adress': '1–2 Queen’s Gardens Bayswater, London W2 3BA England', 'Ranking': '32', 'Amount_Reviews': '400 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d1575619-Reviews-Inhabit_Queen_s_Gardens-London_England.html'}
# {'Name': 'The Savoy', 'Adress': 'The Strand, London WC2R 0EZ England', 'Ranking': '33', 'Amount_Reviews': '7,328 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html'}
# {'Name': 'The Hoxton, Shoreditch', 'Adress': '81 Great Eastern Street Hackney, London EC2A 3HU England', 'Ranking': '257', 'Amount_Reviews': '6,222 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d621785-Reviews-The_Hoxton_Shoreditch-London_England.html'}
# {'Name': 'The Marylebone', 'Adress': '47 Welbeck Street, London W1G 8DN England', 'Ranking': '65', 'Amount_Reviews': '5,389 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193617-Reviews-The_Marylebone-London_England.html'}
# {'Name': 'President Hotel', 'Adress': '56-60 Guilford Street Bloomsbury, London WC1N 1DB England', 'Ranking': '392', 'Amount_Reviews': '5,076 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d189041-Reviews-President_Hotel-London_England.html'}
# {'Name': 'Staybridge Suites London - Vauxhall, an IHG Hotel', 'Adress': '100 Vauxhall Walk, London SE11 5EL England', 'Ranking': '15', 'Amount_Reviews': '1,573 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d6787576-Reviews-Staybridge_Suites_London_Vauxhall_an_IHG_Hotel-London_England.html'}
# {'Name': 'The Mayfair Townhouse', 'Adress': '27-41 Half Moon Street, London W1J 7BG England', 'Ranking': '84', 'Amount_Reviews': '534 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d21282547-Reviews-The_Mayfair_Townhouse-London_England.html'}
# {'Name': 'ibis Styles London Gloucester Road', 'Adress': '110 Cromwell Road, London SW7 4ES England', 'Ranking': '314', 'Amount_Reviews': '403 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html'}
# {'Name': 'Sea Containers London', 'Adress': '20 Upper Ground, London SE1 9PD England', 'Ranking': '140', 'Amount_Reviews': '6,273 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d6161763-Reviews-Sea_Containers_London-London_England.html'}
# {'Name': 'London Marriott Hotel County Hall', 'Adress': 'Westminster Bridge Road London County Hall, London SE1 7PB England', 'Ranking': '125', 'Amount_Reviews': '3,726 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d195225-Reviews-London_Marriott_Hotel_County_Hall-London_England.html'}
# {'Name': 'The Royal Horseguards', 'Adress': '2 Whitehall Court, London SW1A 2EJ England', 'Ranking': '300', 'Amount_Reviews': '7,055 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193079-Reviews-The_Royal_Horseguards-London_England.html'}
# {'Name': 'Novotel London Bridge Hotel', 'Adress': '53-61 Southwark Bridge Road, London SE1 9HH England', 'Ranking': '208', 'Amount_Reviews': '3,022 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d273194-Reviews-Novotel_London_Bridge_Hotel-London_England.html'}
# {'Name': 'Covent Garden Hotel', 'Adress': '10 Monmouth Street, London WC2H 9HB England', 'Ranking': '46', 'Amount_Reviews': '1,271 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d188937-Reviews-Covent_Garden_Hotel-London_England.html'}
# {'Name': 'Canopy by Hilton London City', 'Adress': '11-15 Minories, London EC3N 1AX England', 'Ranking': '37', 'Amount_Reviews': '852 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23246836-Reviews-Canopy_by_Hilton_London_City-London_England.html'}
# {'Name': 'Premier Inn London County Hall Hotel', 'Adress': 'Belvedere Road, London SE1 7PB England', 'Ranking': '267', 'Amount_Reviews': '11,029 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-
reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d555057-Reviews-Ibis_London_City_Shoreditch-London_England.html'}
# {'Name': 'The Westbourne Hyde Park Hotel London', 'Adress': '51 Gloucester Terrace, London W2 3DQ England', 'Ranking': '197', 'Amount_Reviews': '828 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d10723260-Reviews-The_Westbourne_Hyde_Park_Hotel_London-London_England.html'}
# {'Name': 'Dolphin Hotel', 'Adress': '32-34 Norfolk Square, London W2 1RS England', 'Ranking': '629', 'Amount_Reviews': '851 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d192078-Reviews-Dolphin_Hotel-London_England.html'}
# {'Name': 'ibis Styles London Gloucester Road', 'Adress': '110 Cromwell Road, London SW7 4ES England', 'Ranking': '314', 'Amount_Reviews': '403 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html'}
# https://www.tripadvisor.co.uk/Hotels-g186338-oa120-London_England-Hotels.html
# {'Name': 'The Savoy', 'Adress': 'The Strand, London WC2R 0EZ England', 'Ranking': '33', 'Amount_Reviews': '7,328 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html'}
# {'Name': 'The Mandeville Hotel', 'Adress': 'Mandeville Place Marylebone, London W1U 2BE England', 'Ranking': '217', 'Amount_Reviews': '3,214 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193053-Reviews-The_Mandeville_Hotel-London_England.html'}
# {'Name': 'citizenM London Victoria Station', 'Adress': '292 Vauxhall Bridge Road, London SW1V 1AE England', 'Ranking': '160', 'Amount_Reviews': '264 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d24140654-Reviews-CitizenM_London_Victoria_Station-London_England.html'}
# {'Name': 'hub by Premier Inn London Covent Garden hotel', 'Adress': "110 St Martin's Ln, London WC2N 4BA England", 'Ranking': '379', 'Amount_Reviews': '4,786 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d7132928-Reviews-Hub_by_Premier_Inn_London_Covent_Garden_hotel-London_England.html'}
# {'Name': 'Royal Garden Hotel', 'Adress': '2/24 Kensington High Street, London W8 4PT England', 'Ranking': '331', 'Amount_Reviews': '4,985 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193123-Reviews-Royal_Garden_Hotel-London_England.html'}
# {'Name': 'The Gore', 'Adress': "190 Queen's Gate Kensington, London SW7 5EX England", 'Ranking': '270', 'Amount_Reviews': '1,944 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193122-Reviews-The_Gore-London_England.html'}
# {'Name': 'Central Hotel', 'Adress': '16-18 Argyle Street, London WC1H 8EG England', 'Ranking': '42', 'Amount_Reviews': '686 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d242994-Reviews-Central_Hotel-London_England.html'}
# {'Name': 'Kimpton Fitzroy London', 'Adress': '1-8 Russell Square Bloomsbury, London WC1B 5BE England', 'Ranking': '85', 'Amount_Reviews': '1,561 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193051-Reviews-Kimpton_Fitzroy_London-London_England.html'}
# {'Name': 'Ibis London Earls Court', 'Adress': "47 Lillie Road Earl's Court, London SW6 1UD England", 'Ranking': '421', 'Amount_Reviews': '5,895 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d192139-Reviews-Ibis_London_Earls_Court-London_England.html'}
# {'Name': 'Travelodge London Central Elephant And Castle', 'Adress': '87 A Newington Causeway, London SE1 6DH England', 'Ranking': '2', 'Amount_Reviews': '665 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23324763-Reviews-Travelodge_London_Central_Elephant_And_Castle-London_England.html'}
# {'Name': 'Hampton by Hilton London Waterloo', 'Adress': '157 Waterloo Road, London SE1 8XA England', 'Ranking': '351', 'Amount_Reviews': '4,151 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d5961318-Reviews-Hampton_by_Hilton_London_Waterloo-London_England.html'}
# {'Name': 'Travelodge London Park Royal', 'Adress': '614 Western Avenue Acton, London W3 0TE England', 'Ranking': '464', 'Amount_Reviews': '160 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d224759-Reviews-Travelodge_London_Park_Royal-London_England.html'}
# {'Name': 'ibis Styles London Gloucester Road', 'Adress': '110 Cromwell Road, London SW7 4ES England', 'Ranking': '314', 'Amount_Reviews': '403 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html'}
# {'Name': 'Heeton Concept Hotel - Luma Hammersmith', 'Adress': '28 - 36 Glenthorne Road Hammersmith, London W6 0LS England', 'Ranking': '150', 'Amount_Reviews': '761 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d12146171-Reviews-Heeton_Concept_Hotel_Luma_Hammersmith-London_England.html'}
# {'Name': 'Pestana Chelsea Bridge', 'Adress': '354 Queenstown Road, London SW11 8AE England', 'Ranking': '247', 'Amount_Reviews': '3,422 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d1657540-Reviews-Pestana_Chelsea_Bridge-London_England.html'}
# {'Name': 'Park Plaza London Park Royal', 'Adress': 'Site Office 628 Western Avenue, London W3 0TA England', 'Ranking': '354', 'Amount_Reviews': '1,487 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d11717496-Reviews-Park_Plaza_London_Park_Royal-London_England.html'}
# {'Name': 'Premier Inn London Sutton hotel', 'Adress': 'St. Nicholas Way, London SM1 1AT England', 'Ranking': '462', 'Amount_Reviews': '205 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d17851980-Reviews-Premier_Inn_London_Sutton_hotel-London_England.html'}
# {'Name': 'Pullman London St. Pancras Hotel', 'Adress': '100 - 110 Euston Road, London NW1 2AJ England', 'Ranking': '242', 'Amount_Reviews': '5,982 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d192068-Reviews-Pullman_London_St_Pancras_Hotel-London_England.html'}
# {'Name': 'Canopy by Hilton London City', 'Adress': '11-15 Minories, London EC3N 1AX England', 'Ranking': '37', 'Amount_Reviews': '852 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23246836-Reviews-Canopy_by_Hilton_London_City-London_England.html'}
# {'Name': 'Sonder The Henry', 'Adress': '23 Leinster Gardens, London W2 3AN England', 'Ranking': '1', 'Amount_Reviews': '269 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d21400833-Reviews-Sonder_The_Henry-London_England.html'}
# {'Name': "St Paul's Hotel", 'Adress': '153 Hammersmith Road, London W14 0QL England', 'Ranking': '228', 'Amount_Reviews': '782 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d6619066-Reviews-St_Paul_s_Hotel-London_England.html'}
# {'Name': 'London Marriott Hotel Regents Park', 'Adress': "128 King Henry's Road, London NW3 3ST England", 'Ranking': '427', 'Amount_Reviews': '2,989 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193049-Reviews-London_Marriott_Hotel_Regents_Park-London_England.html'}
# {'Name': 'The Z Hotel Covent Garden', 'Adress': '31-33 Bedford Street Covent Garden, London WC2E 9ED England', 'Ranking': '387', 'Amount_Reviews': '340 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d15360882-Reviews-The_Z_Hotel_Covent_Garden-London_England.html'}
# {'Name': 'Heeton Concept Hotel - Kensington London', 'Adress': '15-25 Hogarth Road Earls Court, London SW5 0QJ England', 'Ranking': '592', 'Amount_Reviews': '1,978 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d7141155-Reviews-Heeton_Concept_Hotel_Kensington_London-London_England.html'}
# {'Name': 'The Savoy', 'Adress': 'The Strand, London WC2R 0EZ England', 'Ranking': '33', 'Amount_Reviews': '7,328 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d187686-Reviews-The_Savoy-London_England.html'}
# {'Name': 'Travelodge London Bethnal Green', 'Adress': '231- 237 Cambridge Heath Road, London E2 0EL England', 'Ranking': '1', 'Amount_Reviews': '1,973 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d3572397-Reviews-Travelodge_London_Bethnal_Green-London_England.html'}
# {'Name': 'Hotel Riu Plaza London Victoria', 'Adress': '1 Neathouse Place, London SW1V 1LH England', 'Ranking': '576', 'Amount_Reviews': '122 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d24161323-Reviews-Hotel_Riu_Plaza_London_Victoria-London_England.html'}
# {'Name': 'Z Hotel Holborn', 'Adress': '75 Kingsway, London WC2B 6SR England', 'Ranking': '606', 'Amount_Reviews': '156 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d19389489-Reviews-Z_Hotel_Holborn-London_England.html'}
# {'Name': 'Arosfa Hotel', 'Adress': '83 Gower Street Fitzrovia, London WC1E 6HJ England', 'Ranking': '230', 'Amount_Reviews': '2,039 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d209146-Reviews-Arosfa_Hotel-London_England.html'}
# {'Name': 'Travelodge London Peckham', 'Adress': '121 Peckham High Street, London SE15 5SF England', 'Ranking': '509', 'Amount_Reviews': '76 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d23804546-Reviews-Travelodge_London_Peckham-London_England.html'}
# {'Name': 'Central Hotel', 'Adress': '16-18 Argyle Street, London WC1H 8EG England', 'Ranking': '42', 'Amount_Reviews': '686 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d242994-Reviews-Central_Hotel-London_England.html'}
# {'Name': 'Merit Kensington Hotel', 'Adress': '12, 16-18 & 24 Penywern Road, London SW5 9ST England', 'Ranking': '675', 'Amount_Reviews': '123 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d17765524-Reviews-Merit_Kensington_Hotel-London_England.html'}
# {'Name': "Wombat's The City Hostel London", 'Adress': 'Flat 7 17 Dock Street, London E1 8LJ England', 'Ranking': '3', 'Amount_Reviews': '1,121 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d7147409-Reviews-Wombat_s_The_City_Hostel_London-London_England.html'}
# {'Name': 'Premier Inn London Hendon The Hyde Hotel', 'Adress': 'Hyde House Exit M1 J4, Take The A41 And Then A5 Towards Edgware - Hendon, London NW9 6LH England', 'Ranking': '484', 'Amount_Reviews': '946 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d6694915-Reviews-Premier_Inn_London_Hendon_The_Hyde_Hotel-London_England.html'}
# {'Name': 'Travelodge London Whetstone', 'Adress': '1446 High Road Whetstone, London N20 9BS England', 'Ranking': '530', 'Amount_Reviews': '797 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d2028066-Reviews-Travelodge_London_Whetstone-London_England.html'}
# {'Name': 'Novotel London Waterloo', 'Adress': '113 Lambeth Road, London SE1 7LS England', 'Ranking': '515', 'Amount_Reviews': '3,931 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d192031-Reviews-Novotel_London_Waterloo-London_England.html'}
# {'Name': 'ibis Styles London Gloucester Road', 'Adress': '110 Cromwell Road, London SW7 4ES England', 'Ranking': '314', 'Amount_Reviews': '403 reviews', 'url': 'https://www.tripadvisor.co.uk/Hotel_Review-g186338-d193142-Reviews-Ibis_Styles_London_Gloucester_Road-London_England.html'}

# %% [markdown]
# ## Closing Remarks
#
# Google Colab is a great platform for code development, enabling seamless collaboration with colleagues without the need to install external libraries and dependencies. However, it's important to note that the free version has limitations on code execution duration. Runtime issues may result in disconnection and code failure. It's essential to anticipate and address potential failures on multiple fronts. For lengthy scraping scripts, it's advisable to run them locally on your computer. Additionally, employing the `try` structure and breaking down procedures into smaller, more manageable steps can enhance code manageability and robustness.
