# %% [markdown]
# # Graphs in Python
#
# ![Pandas](https://seaborn.pydata.org/_static/logo-wide-lightbg.svg)
#
#
# Seaborn is a powerful Python library for statistical data visualization. Built on top of Matplotlib, it provides a high-level interface for creating informative and visually appealing charts with minimal code.
#
# Seaborn is designed to work seamlessly with Pandas DataFrames, allowing you to plot data directly from columns. It automatically handles themes, color palettes, and statistical summaries—making it ideal for exploring relationships and patterns in data.
#
# Common plot types include:
#
# - sns.lineplot() — trends over time or continuous variables
#
# - sns.barplot() — comparisons of categories
#
# - [Gallery](https://seaborn.pydata.org/examples/index.html)
#
# Seaborn automatically adds color, style, and legends—helping you go from raw data to insightful visuals quickly.
#
# ## Installation
#
# `pip install seaborn`

# %% [markdown]
# ## Simple Graph

# %%
import seaborn as sns
import pandas as pd



gsrPath = r"assets\010RC14X.CSV"

df = pd.read_csv(filepath_or_buffer = gsrPath, sep='\t')

df
# Out:
#       Count       Date      Time        Lat      Long  Speed  Altitude  GSR
# 0         0  27/5/2018  15:16:37  51.537693 -0.029900   4.70       0.0  565
# 1         1  27/5/2018  15:16:37  51.537693 -0.029900   4.70      67.6  563
# 2         2  27/5/2018  15:16:38  51.537708 -0.029881   3.11      67.6  563
# 3         3  27/5/2018  15:16:39  51.537716 -0.029865   3.22      67.6  559
# 4         4  27/5/2018  15:16:40  51.537689 -0.029866   6.67      67.6  557
# ...     ...        ...       ...        ...       ...    ...       ...  ...
# 4095   4095  27/5/2018   16:0:50  51.539581 -0.029403   4.39      11.3  515
# 4096   4096  27/5/2018   16:0:51  51.539570 -0.029411   4.39      11.3  512
# 4097   4097  27/5/2018   16:0:51  51.539570 -0.029411   4.39      11.4  516
# 4098   4098  27/5/2018   16:0:52  51.539562 -0.029414   2.83      11.4  510
# 4099   4099  27/5/2018   16:0:52  51.539562 -0.029414   2.83      11.6  515
#
# [4100 rows x 8 columns]

# %%
listCount = df["Count"].tolist()

listGSR = df["GSR"].tolist()

# Set the theme for the plot
# Reference: https://seaborn.pydata.org/tutorial/aesthetics.html

# sns.set_theme(style="darkgrid")
sns.set_theme(style="whitegrid")


lineplot = sns.lineplot(x=listCount, y=listGSR, data=df)

lineplot.figure.savefig("lineplot.pdf")

# %% [markdown]
# **Alternative:**
#
# The above would be *one* option. You can also export the data you need as a .csv file and do the graph in Illustrator:

# %%
new_df_GSR = pd.DataFrame()
new_df_GSR['GSR']= df['GSR']
new_df_GSR.to_csv("GSR.txt", index=False)
#new_df_GSR

# %% [markdown]
# ## Bar Plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


df = pd.read_csv(r"assets\Flickr.csv")
df.head(3)
# Out:
#      p_id        lat       lon             o_id               p_date  \
# 0  214028  51.504265 -0.078659  51035570500@N01  2003-05-24 17:40:38
# 1  436102  51.505937 -0.082182     40385587@N00  2004-03-16 14:02:05
# 2  436113  51.505323 -0.089650     40385587@N00  2004-03-16 14:04:28
#
#    accuracy                          title  \
# 0        16              City Hall, London
# 1        14            Angel. A Figurehead
# 2        14  Sign at London Bridge Station
#
#                                                 tags  \
# 0  london england normanfoster architecture geota...
# 1  london thames ship olympus c740 figurehead wys...
# 2              signs london olympus lee c740 wysiwyg
#
#                                                  url
# 0  https://live.staticflickr.com/1/214028_a96ba3e...
# 1  https://live.staticflickr.com/1/436102_7907e51...
# 2  https://live.staticflickr.com/1/436113_d87fc68...

# %% [markdown]
# Each image can possess numerous tags, located within the "tags" column, separated by a space. To be interpreted by Python, it needs to be converted into a list format, as shown below:
#
# `signs london olympus lee c740 wysiwyg`  &#8594;  `["signs","london","olympus","lee", "c740","wysiwyg"]`
#
# And this is what the `.split()` command does.

# %%
# column_values = df["tags"]
column_values = df["tags"].str.split()

# column_values.head(3)

flat = column_values.explode()
 
counts=flat.value_counts()

dateset=counts.iloc[1:40]
ax = dateset.plot(kind='bar');
#this row saves it as a pdf:
ax.figure.savefig("graph.pdf")

# %%
# look at the count of accuracy

listAccuracy = df["accuracy"].tolist()

sns.histplot(listAccuracy, kde=True)
plt.show()
